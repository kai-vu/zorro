# %% [markdown]
# # Knowledge Graphs Workshop: Pattern exercise
#
# First, we'll load the dataset and do some basic pre-processing.
# Then we'll show the table in a handy interface.

# %%
import pandas as pd
import numpy as np
from itables import show
df = pd.read_csv('Aircraft_Annotation_DataFile.csv')
df.columns = [c.lower() for c in df.columns]
df['problem'] = df['problem'].str.strip('.').str.strip()
df['action'] = df['action'].str.strip('.').str.strip()
show(df)
# Out:
# <table id="itables_ab5c3199_1d74_4ba5_bdf0_cc49d81b87b8" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>ident</th>
#       <th>problem</th>
#       <th>action</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ab5c3199_1d74_4ba5_bdf0_cc49d81b87b8:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[100001, "ENGINE IDLE OVERRIDE KILLED ENGINE", "TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T ADJUST"], [100002, "ENGINE IDLE OVERRIDE KILLED ENGINE", "REMOVED & REPLACED FUEL SERVO"], [100003, "ENGINE IDLE OVERRIDE KILLED ENGINE", "A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO LEAKS NO"], [100004, "HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPARTURE. FULL THR", "PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLUG FOULED"], [100005, "#2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING", "REMOVED & REPLACED GASKETS"], [100006, "ROCKER BOX COVER SCREWS LOOSE (ALL CYL)", "TIGHTENED SCREWS"], [100007, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL)", "TIGHTENED HOSE CLAMPS"], [100008, "#3 INTAKE IS LEAKING", "REMOVED & REPLACED GASKET"], [100009, "#2 INTAKE IS LEAKING", "REMOVED & REPLACED #2 INTAKE GASKET"], [100010, "#4 ROCKER COVER IS LEAKING", "REMOVED & REPLACED #4 ROCKER COVER GASKET"], [100011, "HOLDING SHORT OF RUNWAY, AFTER COMPLETION OF RUN UP, ENGINE", "PERFORMED ENGINE RUN UP, ADJUSTED IDLE & CLEANED SPARK"], [100012, "L/H REAR ENGINE BAFFLE CRACKED", "STOP DRILLED CRACK"], [100013, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYLS)", "TIGHTENED HOSE CLAMPS"], [100014, "#1, 2 & 3 ROCKER BOX COVER GASKETS LEAKING", "INSTALLED NEW ROCKER BOX COVER GASKETS"], [100015, "#2 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #2 ROCKER COVER GASKET"], [100016, "#1 & 3 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #1 & 3 ROCKER COVER GASKET"], [100017, "ROCKER BOX COVER SCREWS LOOSE", "TIGHTENED SCREWS"], [100018, "#1 ENGINE BAFFLE CRACKED", "FABRICATED PATCH OF LIKE MATERIAL & RIVETED IAW"], [100019, "#1 INTAKE GASKET LEAKING", "REPLACED W/ NEW GASKET"], [100020, "ROCKER COVER FOR CYL #1 IS LEAKING", "REPLACED ROCKER COVER"], [100021, "CYL #4 INTAKE LEAKING", "REPLACED GASKET. LEAK CHECK GOOD"], [100022, "#2 & 4 CYLINDER ROCKER COVER GASKETS LEAKING", "REMOVED & REPLACED ROCKER COVER GASKETS. CLEANED LEAKS"], [100023, "ROCKER BOX COVER SCREWS ARE LOOSE", "TIGHTENED SCREWS"], [100024, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL)", "TIGHTENED HOSE CLAMPS"], [100025, "#1 INTAKE GASKET LEAKING", "REMOVED INTAKE TUBE, FOUND TUBE TO BE CRACKED. REMOVED"], [100026, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYLS)", "TIGHTENED HOSE CLAMPS"], [100027, "R/H MAG BLAST TUBE FELL OFF", "REMOVED R/H AFT BAFFLE TO FACILITATE REPAIR. FABRICATED"], [100028, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "INSPECTED CYL 1, 2 & 4 IAW  - CK'ED OK. REMOVED"], [100029, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "PERFORMED COMPRESSION CHECK, CYL #3 INDICATED ZERO PSI"], [100030, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "COMPLETED BAFFLE INSTALL, OIL FILLER TUBE, SPARK PLUGS"], [100031, "#4 ROCKER COVER GASKET LEAKING", "REPLACED GASKET"], [100032, "RIGHT ENG #4 AIR BAFFLE IS CRACKED", "REMOVED & REPLACED #4 AIR BAFFLE"], [100033, "R/H ENG FWD ALT ATTACH BOLT LOOSE", "SECURED ALT ATTACH BOLT & RESAFETIED"], [100034, "L/H ENGINE #4 AFT BAFFLE CRACKED IN MULTIPLE PLACES", "REPLACED BAFFLE ASSY"], [100035, "RIGHT ENG, ALL VALVE COVERS ARE LEAKING", "REMOVED & REPLACED ALL ROCKER GASKETS"], [100036, "L/H ENGINE ALL 4 ROCKER COVER GASKETS LEAKING", "REPLACED ALL ROCKER COVER GASKETS"], [100037, "L/H ENG #2 INTAKE LEAKING", "REMOVED TUBE, FOUND TO BE CRACKED. REMOVED TUBE FROM CO"], [100038, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "RAN A/C, MAGS CHECK GOOD. POWER & LEAK CHECK GOOD"], [100039, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REMOVED #3 CYL, DISCONNECTED FUEL DISTRIBUTOR LINE TO G"], [100040, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REASSEMBLED ENGINE, #3 CYL DRY TAPPET CLEARANCE CHECK G"], [100041, "#4 INTAKE LEAKING", "REMOVED & REPLACED #4 INTAKE GASKET"], [100042, "#3 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #3 ROCKER COVER GASKET"], [100043, "TOP L/H BAFFLE HAS A CRACK", "STOP DRILLED CRACK"], [100044, "OIL  ...

# %% [markdown]
# ## Define a pattern for Problem strings
#
# In this example pattern, we extract the location of the problem, the part, and a problem keyword.
#
# Try to modify the pattern to extract more problem types, or make a different kind of problem pattern!

# %%
loc_pat = '(?:(?:L|R)/H ?(?:REAR )?(?:AFT )?(?:ENG(?:INE)?,? ?)?)?(?:CYL(?:INDER)? ?)?(?:ALL )?(?:#?\d(?: ?. \d)*)?(?: CYL(?:INDER)? ?)?'
problem_pat = (
    '^'
    # The location often mentions the engine side and cylinder number
   f'(?P<loc1>{loc_pat})? ?'
    
    # A part name ends with a letter, ignore the last "S" (for plural words)
    '(?P<part>\w[ \w]+?)S?,? ' 

    f'(?:ON )?(?P<loc2>{loc_pat})? ?'

    # Match the verb but don't extract it
    '(?:IS |ARE |HAS |HAVE |APPEARS TO BE )?(?:A )?(?:POSSIBLE )?(?:EVIDENCE OF )?(?:COMING )?(?:SEVERAL )?(?:SHOWS SIGNS OF )?'

    # Some pre-defined problem keywords to match
    '(?P<problem>(?:OIL )?LEAK(?:ING)?S?|LOOSE|TORN|CRACKED|BROKEN|DAMAGED?|WORN|MISSING|BAD|SHEAR(?:ED)?|BROKE|STUCK|STICK(?:ING)?|DIRTY|DEAD|FAILED|NEEDS?|.*COMPRESSION.*)'

    f',? ?(?:ON )?(?P<loc3>{loc_pat})? ?'
    
    '(?P<rest>.*)'
)
problem_extractions = pe = df['problem'].str.extract(problem_pat)
problem_extractions['part'].replace({'HA': '', 'INDER':'', 'I':'', 'INE': '', 'ON':''}, inplace=True)
def join_cols(row):
    return ' '.join(row[~row.isna()].values.astype(str)) or np.nan
pe['location'] = pe[['loc1', 'loc2', 'loc3']].apply(join_cols, axis=1)
pe.drop(columns=['loc1', 'loc2', 'loc3'], inplace=True)

# Fix compression
comp = (~pe['problem'].isna() & pe['problem'].str.contains('COMPRESSION'))
pe.loc[comp, 'rest'] = pe[comp]['problem'] + pe[comp]['rest']
pe.loc[comp, 'problem'] = 'COMPRESSION'
pe.insert(0, 'id', df['ident'])

pe.to_csv('problem_extractions_regex.csv', index=None)


# Show the most common problem extractions
show(problem_extractions.fillna('').value_counts())
# Out:
# <table id="itables_b712d72e_5b93_4ca7_84bd_b6512ab06738" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th>part</th>
#       <th>problem</th>
#       <th>rest</th>
#       <th>location</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_b712d72e_5b93_4ca7_84bd_b6512ab06738:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[100001, "", "", "", "", 1], [104050, "INTAKE GASKET", "LEAKING", "", "CYL #4  ", 1], [104120, "INTAKE GASKET", "LEAKING", "", " #2, 3, 4 ", 1], [104119, "INTAKE GASKET", "LEAKING", "", "CYL #4  ", 1], [104118, "", "", "", "", 1], [104117, "BAFFLE SCREW", "MISSING", "", "CYL #2  L/H ENGINE", 1], [104116, "", "", "", "", 1], [104115, "", "", "", "", 1], [104114, "", "", "", "", 1], [104113, "", "", "", "", 1], [104112, "", "", "", "", 1], [104111, "BAFFLE TIE ROD", "BAD", "", "L/H ENG   ", 1], [104110, "", "", "", "", 1], [104109, "", "", "", "", 1], [104108, "", "", "", "", 1], [104107, "", "", "", "", 1], [104106, "ROCKER COVER GASKET", "LEAKING", "", " CYL #2 ", 1], [104105, "INTAKE", "LEAKING", "", "#4  ", 1], [104104, "ROCKER COVER GASKET", "LEAKING", "", " 1, 2, 3 & 4 R/H ENGINE", 1], [104103, "SEAL", "LOOSE", "ENGINE COWL, ABOVE L/H & R/H OIL COOLERS (BLAC", "  ", 1], [104102, "INTAKE GASKET", "LEAKING", "", "R/H ENG CYL #3  ", 1], [104101, "ROCKER COVER", "LEAKING", "", "#1 & 2  L/H ENGINE", 1], [104100, "", "", "", "", 1], [104121, "", "", "", "", 1], [104122, "", "", "", "", 1], [104123, "INTAKE GASKE", "LEAKING", "", "#2 CYL   ", 1], [104135, "BAFFLE PLUG", "DAMAGED", "", "  ", 1], [104144, "ENG", "COMPRESSION", "COMPRESSION 55 LBS (RINGS LEAKING)", "R/H  #2 ", 1], [104143, "ENG", "COMPRESSION", "COMPRESSION 55 LBS (RINGS LEAKING)", "R/H  #2 ", 1], [104142, "INTAKE", "LEAKS", "", "R/H ENG #2  ", 1], [104141, "ROCKER COVER", "LEAKING", "", "#2  R/H ENGINE", 1], [104140, "INTAKE", "LEAKING", "", "#1 & 2  L/H ENGINE", 1], [104139, "", "", "", "", 1], [104138, "INTAKE GASKET", "LEAKING", "", "L/H ENGINE CYL #3 & 4  ", 1], [104137, "BAFFLE", "CRACKED", "", "  R/H ENGINE #1 CYLINDER", 1], [104136, "BAFFLE SEAL", "LOOSE", "", "L/H ENGINE   ", 1], [104134, "INTAKE", "LEAKING", "", "#2  ", 1], [104124, "ROCKER COVER SCREW", "MISSING", "", "#4  ", 1], [104133, "ROCKER COVER GASKET", "LEAKING", "", "CYL #4  ", 1], [104132, "INTAKE GASKET", "LEAKING", "", "CYL #2, 3  ", 1], [104131, "", "", "", "", 1], [104130, "INTAKE GASKET", "LEAKING", "", "CYL #3  ", 1], [104129, "", "", "", "", 1], [104128, "", "", "", "", 1], [104127, "", "", "", "", 1], [104126, "INTAKE", "LEAKING", "", "#2 & 4  ", 1], [104125, "SIDE BAFFLE SCREW", "MISSING", "", "#3 CYL   ", 1], [104099, "INTAKE GASKET", "LEAKING", "", "#2  ", 1], [104098, "ROCKER COVER GASKET", "LEAKING", "", "CYL #1 & 2  ", 1], [104097, "INTAKE GASKET", "LEAKING", "", "CYL #4  ", 1], [104062, "INTAKE GASKET", "LEAKING", "", "#2  ", 1], [104071, "", "", "", "", 1], [104070, "LH OIL COOLER", "NEEDS", "TO BE CHANGED", "  ", 1], [104069, "LEFT REAR BAFFLE", "CRACKED", "", "L/H ENGINE,   ", 1], [104068, "OIL COOLER", "NEEDS", "TO BE CHANGED", "R/H   ", 1], [104067, "BAFFLE BRACKET BY OIL COOLER", "CRACKED", "", "  ", 1], [104066, "OIL COOLER", "NEEDS", "TO BE CHANGED", "R/H   ", 1], [104065, "LH OIL COOLER", "NEEDS", "TO BE CHANGED", "  ", 1], [104064, "OIL COOLER", "NEEDS", "TO BE CHANGED", "R/H   ", 1], [104063, "LH OIL COOLER", "NEEDS", "TO BE CHANGED", "  ", 1], [104061, "", "", "", "", 1], [104073, "BAFFLE PLUG", "MISSING", "", "#3 CYL   ", 1], [104060, "", "", "", "", 1], [104059, "", "", "", "", 1], [104058, "ROCKER BOX COVER GASKET", "LEAKING", "", "#2  ", 1], [104057, "", "", "", "", 1], [104056, "", "", "", "", 1], [104055, "INTAKE GASKET", "LEAKING", "", "#2, 3, 4  L/H ENG", 1], [104054, "INTAKE TUBE GASKET", "LEAKING", "", "R/H ENG #3  ", 1], [104053, "", "", "", "", 1], [104052, "", "LEAKING", "ROCKER COVER GASKETS", "R/H ENG #1, 2, 4  ", 1], [104072, "INTAKE GASKET", "LEAKING", "", "#2 CYL   ", 1], [104074, "", "", "", "", 1], [104096, "", "", "", "", 1], [104086, "", "COMPRESSION", "NO COMPRESSION (0/80), AIR COMING OUT EXHAUS", "#4 CYLINDER   ", 1], [104095, "ROCKER COVER", "LEAKING", "", "#4  ", 1], [104094, "INTAKE", "LEAKING", "", "#3  ", 1], [104093, "INTAKE GASKET", "LEAKING", "", "#3  ", 1], [104092, "LWR FWD SEAL", "NEEDS", "RTV ABOVE ENG INTAKE" ...

# %%
pc = pe['part'].value_counts().drop(['ENGINE'])
part_pat = '|'.join(pc[(pc.index.str.len()>3) & (pc>=3)].index)
locs = pe['location'].str.replace(' +', ' ', regex=True).str.strip().unique()
loc_pat = '|'.join(locs[pd.Series(locs).str.len()>1])
df_nopart_noloc = df.loc[(df['problem'].str.count(part_pat)==0) & (df['problem'].str.count(loc_pat)==0)]
df_nopart_noloc['problem'].to_csv('problems_nopart_noloc.csv', index=None)
show(df_nopart_noloc)
# Out:
# <table id="itables_f10be9a0_f859_41d9_8d43_63eeefc86342" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ident</th>
#       <th>problem</th>
#       <th>action</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f10be9a0_f859_41d9_8d43_63eeefc86342:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[0, 100001, "ENGINE IDLE OVERRIDE KILLED ENGINE", "TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T ADJUST"], [1, 100002, "ENGINE IDLE OVERRIDE KILLED ENGINE", "REMOVED & REPLACED FUEL SERVO"], [2, 100003, "ENGINE IDLE OVERRIDE KILLED ENGINE", "A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO LEAKS NO"], [3, 100004, "HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPARTURE. FULL THR", "PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLUG FOULED"], [10, 100011, "HOLDING SHORT OF RUNWAY, AFTER COMPLETION OF RUN UP, ENGINE", "PERFORMED ENGINE RUN UP, ADJUSTED IDLE & CLEANED SPARK"], [27, 100028, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "INSPECTED CYL 1, 2 & 4 IAW  - CK'ED OK. REMOVED"], [28, 100029, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "PERFORMED COMPRESSION CHECK, CYL #3 INDICATED ZERO PSI"], [29, 100030, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "COMPLETED BAFFLE INSTALL, OIL FILLER TUBE, SPARK PLUGS"], [37, 100038, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "RAN A/C, MAGS CHECK GOOD. POWER & LEAK CHECK GOOD"], [38, 100039, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REMOVED #3 CYL, DISCONNECTED FUEL DISTRIBUTOR LINE TO G"], [39, 100040, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REASSEMBLED ENGINE, #3 CYL DRY TAPPET CLEARANCE CHECK G"], [43, 100044, "OIL DIPSTICK OIL STICK IS LOOSE", "REMOVED & REPLACED DIPSTICK"], [53, 100054, "DURING IDLE CHECK ON RUN UP, ENGINE QUIT. RESTART ENGINE", "ADJUSTED IDLE SETTING, IDLE INDICATING 650 RPM DURING R"], [61, 100062, "DURING GROUND RUN PILOT NOTICED HIGH OIL PRESS (ENGINE)", "ADJUSTED ENGINE OIL PRESS RELIEF VALVE"], [62, 100063, "DURING GROUND RUN PILOT NOTICED HIGH OIL PRESS (ENGINE)", "A/C WAS GROUND RAN TO FULL PWR, OIL PRESS CHECKED OK"], [63, 100064, "STUDENT COULDN'T START A/C", "STARTED A/C FOR STUDENT"], [65, 100066, "AFTER LANDING, A/C IDLE @ 970 RPM", "ADJUSTED IDLE SETTING BY LOWERING. IDLE SETTING W/IN MA"], [66, 100067, "FUEL PRESS 32 - 33 W/ JUMPS INTO RED", "CLEANED TRANSDUCER GROUND PATH. FUEL PRESS CHECKED GOOD"], [70, 100071, "LAST DAILY SHUT DOWN IDLE OVER RIDE SPEED CHECK - ENGINE RPM", "RAN A/C, ADJUSTED IDLE SPEED. CHECKS GOOD"], [75, 100076, "ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", "RAN A/C, OPS & LEAK CHECK GOOD"], [76, 100077, "ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", "RAN A/C. CONFIRMED DISCREPANCY. FOUND #3 CYL HAD VERY L"], [77, 100078, "ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", "COMPLETED REASSEMBLY OF #3 CYL ASSY. INSTALLED NEW INTA"], [78, 100079, "ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", "REMOVED #3 CYL. INSTALLED SERVICEABLE CYL ASSY. TORQUED"], [79, 100080, "ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", "DISASSEMBLED #1, 2, 4 EXHAUST VALVES, REAMED GUIDES IAW"], [84, 100085, "ENGINE WOULD NOT START", "STARTED ENGINE, LEANED MIXTURE TO CLEAN SPARK PLUGS. MA"], [97, 100098, "ROUGH RUNNING ENGINE ON START. ENGINE RAN SMOOTHER AS IT WAR", "FINISHED REAMING ALL 4 EXHAUST VALVE GUIDES. INSTALLED"], [98, 100099, "ROUGH RUNNING ENGINE ON START. ENGINE RAN SMOOTHER AS IT WAR", "REMOVED COWLING, REMOVED ALL SPARK PLUGS. REAMED #3 EXH"], [100, 100101, "OIL FOUND ON ENTIRE RIGHT SIDE OF FUSELAGE", "REMOVED COWLING, CLEANED ENGINE, PERFORMED ENGINE RUN U"], [104, 100105, "ENGINE DIED DURING MAG CK", "STARTED A/C USING FLOODED START PROCEDURE & RAN A/C TO"], [129, 100130, "ENGINE STARTED RUNNING ROUGH SHORTLY AFTER TAKEOFF & LANDED", "RAN ENGINE BRIEFLY & NOTED THAT ENGINE WAS NOT RUNNING"], [130, 100131, "ENGINE STARTED RUNNING ROUGH SHORTLY AFTER TAKEOFF & LANDED", "FREED EXHAUST VALVE, INSPECTED & FOUND TO BE SERVICEABL"], [134, 100135, "CHT NEEDLE BOUNCES & HAD ENGINE RUN ROUGH MOMENTARILY", "REMOVED & REPLACED CHT PROBE. INSP ENGINE, NO DEFECTS N"], [135, 100136, "NOTED WEAR ON ENGINE MOUNT CAUSED BY ENGINE BREATHER SUPPORT", "OPS & LEAK CHECK GOOD"], [136, 100137, "NOTED WEAR ON ENGINE  ...

# %%
# Show non-matching problems
problems_nomatch = df['problem'].loc[problem_extractions.isna().all(axis=1)]
problems_nomatch.to_csv('problems_nomatch.csv', index=None)
show(problems_nomatch.value_counts().rename('count'))
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_4674c26d_f566_4734_86d5_ddbd3a3966b5" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     $(document).ready(function () {
#         document.querySelectorAll("#itables_4674c26d_f566_4734_86d5_ddbd3a3966b5:not(.dataTable)").forEach(table => {
#             // Define the table data
#             const data = [["ENGINE REQUIRES DISASSEMBLY & INSPECTION AFTER PROP STRIKE", 11], ["HIGH FREQUENCY VIBRATION FELT WHILE RUNNING UP AT 2000 RPM", 8], ["ENGINE REQUIRES OVERHAUL", 8], ["START ASSIST", 8], ["ON ENGINE START, ENGINE WAS UNUSUALLY ROUGH. ATTEMPTED TO LE", 7], ["INSPECTED & FOUND CRANKSHAFT TO BE GOUGED BEHIND CRANKSHAFT", 7], ["MX FLIGHT REQUIRED TO CK FOR ABNORMAL ENGINE ROUGHNESS IN FL", 6], ["R/H ENGINE RUNNING ROUGH. DURING RUN UP ENGINE WAS VIOLENTLY", 6], ["L/H ENGINE HAD C CLIP IN OIL SCREEN", 6], ["PERFORMING GROUND REF MAN, THROTTLE WAS AT 1600 RPM, THROTTL", 6], ["MANUFACTURER REQUESTED CONNECTING ROD EXCHANGE", 5], ["ENGINE VERY ROUGH AFTER START - DOES NOT RUN AT IDLE", 5], ["ROUGH RUNNING ENGINE IN FLIGHT. PARTIAL POWER LOSS, LITTLE T", 5], ["DURING AUTO RECOVERY ENGINE RPM GOT TO 3500", 5], ["ENGINE REQUIRES TIME CHANGE", 5], ["ENGINE STARTED RUNNING ROUGH & VIBRATING A LOT", 5], ["IN STRAIGHT & LEVEL FLIGHT EXPERIENCED 2 VIBRATIONS W/ A/C Y", 5], ["DURING STEEP TURNS, ENGINE BEGAN TO STRUGGLE & COUGHED OFTEN", 5], ["ROUGH ENGINE W/ OIL LEAK", 5], ["WHILE FOGGING #2 CYL, TIP FROM SPRAYER NOZZLE CAME INTO CONT", 5], ["ENGINE RUNNING VERY ROUGH & SHAKING AFTER START UP", 5], ["ON RUN UP; R/H ENG, L/H MAG FAILED MAG CK. CYL #1 HAD NO TEM", 5], ["LEFT ENG BACK FIRED WHEN BROUGHT TO 1800 RPM. RIGHT MAG DROP", 5], ["A/C WON'T START", 4], ["ENGINE IDLES VERY IRRATICALLY BELOW 1150 RPM", 4], ["#2 CYL \"MISSING\" ON RUN UP (RUNS ROUGH)", 4], ["ROUGH ENGINE START UNUSUAL INDICATION CYL #4, LOWER TEMPERAT", 4], ["ENGINE CHANGE REQUIRED", 4], ["ENGINE STARTED & SEEMED TO BE RUNNING FINE. SUDDENLY ENGINE", 4], ["STARTED ENGINE & IT RAN WELL FOR ABOUT 30 SECONDS BEFORE LOS", 4], ["FOD ON TOP OF ENGINE", 4], ["ENGINE OVERSPEED UP TO 3400 RPM @ TERMINATION OF AN AUTO", 4], ["AFTER ENGINE START UP, NOTICED VIBRATION & ROUGH RUNNING ENG", 4], ["AFTER ENGINE START, ENGINE RAN ROUGH BUT THEN SMOKED OUT. AF", 4], ["ENGINE IS TIMED OUT", 4], ["OIL PRESSURE READ 100-105 PSI IN TRAFFIC PATTERN", 4], ["ROD CHANGE PER LYCOMING", 4], ["ON RUN UP, L/H MAG DROPPED 350 RPM", 4], ["AFTER ENGINE START, THERE WAS ENGINE VIBRATION. SUSPECT CYL", 4], ["4TH STAGE NOZZLE HAS SEVERAL CRACKS IN IT", 4], ["REPLACE R/H ENGINE TORQUEMETER HOSES", 3], ["REPLACE L/H ENGINE TORQUEMETER HOSES", 3], ["ENGINE RAN ROUDH, IDLE LOW, WOULDN'T GO TO FULL POWER", 3], ["UNUSUAL ATTITUDE POWER WAS ADDED & ENGINE REACHED APPROX 280", 3], ["OIL COMING OUT OF TOP L/H COWLING", 3], ["STUCK VALVE ON #3 CYL. DAMAGE TO PUSH ROD & HOUSING", 3], ["RAN SMOOTHLY AFTER ENGINE START LEAN PROCEDURE, THEN RAN VER", 3], ["DURING CRUISE, ENGINE BECAME INCREDIBLY ROUGH. ENGINE CONTIN", 3], ["DURING ENGINE START, ENGINE WAS RUNNING VERY ROUGH. WENT THR", 3], ["ROUGH ENGINE", 3], ["ENGINE RPM DROPPED 200-300 RPM SUDDENLY, ACCOMPANIED BY STRO", 3], ["PROP OVERSPEED; RPM ABOUT 2850 W/ PROP CONT AT HIGH RPM IN L", 3], ["ROUGH CHOPPING NOISE COMING FROM ENGINE ON APPLICATION OF FU", 3], ["R/H ENGINE SPUTTERING @ 1700 RPM, AS INCREASED THROTTLE RPM", 3], ["ENGINE STARTED NORMALLY, 60 SECS AFTER START, ENGINE BEGAN T", 3], ["#1 L/H ENG, ROCKER COVER HAS DAMAGE", 3], ["PILOT REQUIRES START ASSIST", 3], ["ENGINE IDLE OVERRIDE KILLED ENGINE", 3], ["ENGINE RAN ROUGH. AFTER RPM'S WERE STAB", 3], ["IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", 3], ["NOTED WEAR ON ENGINE MOUNT CAUSED BY ENGINE BREATHER SUPPORT", 3], ["COMPRESSION IS LOW #2 CYLINDER", 3], ["ENGINE STARTED RUNNING ROUGH & BACK FIRING. BOTH POWER REDUC", 3], ["#3 & 4 CYL WERE REMOVED BY OFF SITE MAINTENANCE", 3], ["ON A/C RUN UP, L/H PROP TIP WAS DAMAGED", 3], ["REMOVE ENGINE TO FACILITATE FIREWALL REPAIR", 3], ["LH/ ENG #2 CYL HAS LOW COMPRESSION", 3], ["DURING SHUT DOWN CHECKLIST, WHEN PUT THROTTLE IDLE, ENGINE S", 3], ["AFTER START, ENGINE RAN CONSISTANTLY ROUGH", 3], ["#4 COMPRESSION IS 20/80", 3], ["ON POST RUN UP, FOUND ENGINE RUNNING ROUGH AT IDLE. #2 CYL C", 3], ["ON START UP, ENGINE BEGA ...

# %% [markdown]
# ## Define a pattern for Action strings
#
# In this example pattern, we extract the location of the action, the part, and an action keyword.
#
# Try to modify the pattern to extract more action types, or make a different kind of action pattern!

# %%
action_pat = (
    '^(?:REMOVED & )?(?:RE)?'
    # Pre-defined action keywords
    '(?P<action>REPLACED|TIGHTENED|SECURED|ATTACHED|FASTENED|TORQUED|CLEANED|STOP DRILLED) ?'

    # The location often mentions the engine side and cylinder number
    '(?P<location>(?:(?:L|R)/H (?:ENG )?)?(?:CYL ?)?(?:#?\d(?: ?. \d)*)(?: CYL ?)?)? ?'

    # Often, replacements mention "W/ NEW"; ignore it
    '(?:W/ )?(?:NEW )?'

    # A part name ends with a letter, ignore the last "S" (for plural words)
    '(?P<part>.*?\w)S?'
    
    '(?: W/ .*)?$'
)
action_extractions = df['action'].str.extract(action_pat)
action_extractions.insert(0, 'id', df['ident'])
action_extractions.to_csv('action_extractions_regex.csv', index=None)

show(action_extractions.fillna('').value_counts())
# Out:
# <table id="itables_a45b9cec_b1ad_4c12_b3a7_2123e1859b18" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th>action</th>
#       <th>location</th>
#       <th>part</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.11/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a45b9cec_b1ad_4c12_b3a7_2123e1859b18:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[100001, "", "", "", 1], [104050, "REPLACED", "", "INTAKE GASKET", 1], [104120, "REPLACED", "", "GASKET", 1], [104119, "REPLACED", "#4", "INTAKE GASKET", 1], [104118, "SECURED", "", "ENGINE BAFFLE", 1], [104117, "", "", "", 1], [104116, "", "", "", 1], [104115, "STOP DRILLED", "", "CRACK", 1], [104114, "ATTACHED", "", "ENGINE BAFFLE SEAL", 1], [104113, "REPLACED", "", "TIE ROD", 1], [104112, "STOP DRILLED", "", "CRACK", 1], [104111, "", "", "", 1], [104110, "REPLACED", "", "ENGINE DRIVEN FUEL PUMP", 1], [104109, "", "", "", 1], [104108, "", "", "", 1], [104107, "", "", "", 1], [104106, "REPLACED", "", "GASKET", 1], [104105, "REPLACED", "", "INTAKE GASKET", 1], [104104, "REPLACED", "", "ROCKER COVER GASKET", 1], [104103, "SECURED", "", "SEAL ON LOWER ENGINE COWLS, L/H & R/H, ABOVE", 1], [104102, "REPLACED", "", "INTAKE GASKET", 1], [104101, "REPLACED", "", "GASKET", 1], [104100, "", "", "", 1], [104121, "", "", "", 1], [104122, "", "", "", 1], [104123, "REPLACED", "", "GASKET", 1], [104135, "REPLACED", "", "BAFFLE PLUG", 1], [104144, "", "", "", 1], [104143, "", "", "", 1], [104142, "REPLACED", "", "GASKET", 1], [104141, "REPLACED", "", "GASKET", 1], [104140, "REPLACED", "", "GASKET", 1], [104139, "", "", "", 1], [104138, "", "", "", 1], [104137, "STOP DRILLED", "", "CRACK", 1], [104136, "REPLACED", "", "RIVET ON BAFFLE SEAL", 1], [104134, "REPLACED", "", "INTAKE GASKET", 1], [104124, "", "", "", 1], [104133, "REPLACED", "", "ROCKER COVER GASKET", 1], [104132, "REPLACED", "", "GASKET", 1], [104131, "", "", "", 1], [104130, "REPLACED", "", "GASKET", 1], [104129, "", "", "", 1], [104128, "", "", "", 1], [104127, "", "", "", 1], [104126, "REPLACED", "", "INTAKE GASKET", 1], [104125, "", "", "", 1], [104099, "REPLACED", "", "INTAKE GASKET", 1], [104098, "REPLACED", "", "ROCKER COVER GASKET", 1], [104097, "REPLACED", "", "GASKET", 1], [104062, "REPLACED", "", "INTAKE GASKET", 1], [104071, "", "", "", 1], [104070, "", "", "", 1], [104069, "REPLACED", "", "BAFFLING SECTION", 1], [104068, "", "", "", 1], [104067, "REPLACED", "", "BRACKET", 1], [104066, "", "", "", 1], [104065, "", "", "", 1], [104064, "", "", "", 1], [104063, "", "", "", 1], [104061, "", "", "", 1], [104073, "", "", "", 1], [104060, "STOP DRILLED", "", "CRACK", 1], [104059, "STOP DRILLED", "", "CRACK", 1], [104058, "", "", "", 1], [104057, "ATTACHED", "", "CABLE & HOSE", 1], [104056, "REPLACED", "", "ADEL CLAMP", 1], [104055, "REPLACED", "", "L/H ENG INTAKE GASKET", 1], [104054, "", "", "", 1], [104053, "", "", "", 1], [104052, "REPLACED", "", "GASKET", 1], [104072, "", "", "", 1], [104074, "", "", "", 1], [104096, "", "", "", 1], [104086, "", "", "", 1], [104095, "REPLACED", "", "ROCKER COVER GASKET", 1], [104094, "REPLACED", "", "INTAKE GASKET", 1], [104093, "", "", "", 1], [104092, "", "", "", 1], [104091, "", "", "", 1], [104090, "", "", "", 1], [104089, "STOP DRILLED", "", "CRACK @ FWD BAFFLE BY HEAT INLET ON AFT SI", 1], [104088, "", "", "", 1], [104087, "", "", "", 1], [104085, "", "", "", 1], [104075, "REPLACED", "", "INTAKE GASKET", 1], [104084, "", "", "", 1], [104083, "", "", "", 1], [104082, "", "", "", 1], [104081, "", "", "", 1], [104080, "REPLACED", "", "GASKET", 1], [104079, "REPLACED", "", "GASKET", 1], [104078, "", "", "", 1], [104077, "REPLACED", "", "ROCKER COVER GASKET", 1], [104076, "REPLACED", "", "GASKET", 1], [104145, "", "", "", 1], [104146, "TIGHTENED", "", "SCREW", 1], [104147, "CLEANED", "", "SNIFFLER VALVE", 1], [104207, "CLEANED", "", "SNIFFLER VALVE", 1], [104216, "REPLACED", "", "INTAKE GASKET", 1], [104215, "REPLACED", "", "INTAKE GASKET", 1], [104214, "REPLACED", "", "GASKET", 1], [104213, "REPLACED", "", "GASKET", 1], [104212, "REPLACED", "", "RIVET", 1], [104211, "", "", "", 1], [104210, "CLEANED", "", "OIL COOLER", 1], [104209, "REPLACED", "", "INTAKE GASKET", 1], [104208, "", "", "", 1], [104206, "", "", "", 1], [104218, "", "", "", 1], [104205, "SECURED", "", "BAFFLE SEAL", 1], [104204, "REPLACED", "", "GASK ...

# %%
# Show non-matching actions
show(df['action'].loc[action_extractions.isna().all(axis=1)])

# %% [markdown]
# ## Loading extractions into graph
#
# Now, we'll transform our extractions into graphs and load them into the Knowledge Graph.

# %%
from helperFunctions import obj_to_triples
import re
from rdflib import Graph, URIRef, BNode, Literal, RDF, RDFS, DC, Namespace
ZORRO = Namespace("https://zorro-project.nl/example/")

def create_problem_obj(row):
    ent = ZORRO[f'problem{row.ident}']
    
    problem_match = re.search(problem_pat, row.problem)
    problem_fields = problem_match.groupdict() if problem_match else {}
    action_match = re.search(action_pat, row.action)
    action_fields = action_match.groupdict() if action_match else {}

    def camelcase(fields, name):
        # Convert string into a clean CamelCase name
        return re.subn('\W', '', fields.get(name, '').title())[0]
    
    return {
        '@id': ent,
        RDF.type: ZORRO[camelcase(problem_fields, 'problem') + 'Problem'],
        DC.description: Literal(row.problem),
        
        ZORRO.involvedPart: {
            RDF.type: ZORRO[camelcase(problem_fields, 'part') + 'Part'],
            ZORRO.location: Literal((problem_fields.get('location') or '').strip())
        } if problem_fields.get('part') else None,
        
        ZORRO.requiredAction: {
            DC.description: Literal(row.action),
            RDF.type: ZORRO[camelcase(action_fields, 'action') + 'Action'],
            
            ZORRO.involvedPart: {
                RDF.type: ZORRO[camelcase(action_fields, 'part') + 'Part'],
                ZORRO.location: Literal((action_fields.get('location') or '').strip())
            } if action_fields.get('part') else None
        }
    }

# Show the turtle serialization of the first 5 extractions
g = Graph()
g.namespace_manager.bind('', ZORRO)
for obj in df.head(5).apply(create_problem_obj, axis=1):
    for t in obj_to_triples(obj):
        g.add(t)
print(g.serialize())

# %%
# Run on entire dataset, takes a few seconds!
g = Graph()
g.namespace_manager.bind('', zorro)
for obj in df.apply(create_problem_obj, axis=1):
    for t in obj_to_triples(obj):
        g.add(t)
g.serialize('pattern_graph.ttl')

# %%
# %load_ext ipython_sparql_pandas
from helperFunctions import GraphDB

db = GraphDB()
repo_name = 'zorro'
db.create_repo(repo_name).text

response = db.load_data(repo_name, 'pattern_graph.ttl', 
          graph_name = "https://zorro-project.nl/example/PatternGraph")
print(response.text)

# %%
# %%sparql http://localhost:{db.port}/repositories/{repo_name} -s result
# PREFIX : <https://zorro-project.nl/example/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# select (count(*) as ?c) where {
# 	?prob a :Problem .
# }

# %% [markdown]
# ### But didn't we add many more instances ..?
#
# These are only the ones for which we couldn't extract a more specific problem class!
#
# To get our instances, we also load our schema about maintenance:

# %%
response = db.load_data(repo_name, 'maintenance.ttl', 
          graph_name = "https://zorro-project.nl/example/MaintenanceGraph")
print(response.text)

# %%
# %%sparql http://localhost:{db.port}/repositories/{repo_name} -s result
# PREFIX : <https://zorro-project.nl/example/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# select (count(*) as ?c) where {
# 	 ?prob a :Problem .
# }

# %%
# %%sparql http://localhost:{db.port}/repositories/{repo_name} -s result
# PREFIX : <https://zorro-project.nl/example/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# select ?problemClass (count(*) as ?count) where {
#     ?prob a :Problem .
#     ?prob a ?problemClass .
# }
# GROUP BY ?problemClass

# %%
result.set_index('problemClass')['count'].plot.barh()
