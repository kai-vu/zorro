# %% [markdown]
# # Knowledge Graphs Workshop exercise 3: GPT
#
# Task: change the prompt and see if you can make GPT extract more complex problems or actions!

# %%
import pandas as pd
from itables import show
df = pd.read_csv('Aircraft_Annotation_DataFile.csv')
df.columns = [c.lower() for c in df.columns]
df['problem'] = df['problem'].str.strip('.').str.strip()
df['action'] = df['action'].str.strip('.').str.strip()
show(df)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_8f866031_fcc2_4be0_80e0_e7b25812fe40" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>ident</th>
#       <th>problem</th>
#       <th>action</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     $(document).ready(function () {
#         document.querySelectorAll("#itables_8f866031_fcc2_4be0_80e0_e7b25812fe40:not(.dataTable)").forEach(table => {
#             // Define the table data
#             const data = [[100001, "ENGINE IDLE OVERRIDE KILLED ENGINE", "TRIED TO ADJUST IDLE SEVERAL TIMES, WOULDN'T ADJUST"], [100002, "ENGINE IDLE OVERRIDE KILLED ENGINE", "REMOVED & REPLACED FUEL SERVO"], [100003, "ENGINE IDLE OVERRIDE KILLED ENGINE", "A/C WAS RUN UP, SET IDLE SPEED, MIXTURE OK, NO LEAKS NO"], [100004, "HAD ENGINE CHOKE & BRIEFLY LOSE POWER ON DEPARTURE. FULL THR", "PERFORMED ENGINE RUN UP, FOUND CYL 2 LOWER PLUG FOULED"], [100005, "#2 & 4 CYL ROCKER COVER GASKETS ARE LEAKING", "REMOVED & REPLACED GASKETS"], [100006, "ROCKER BOX COVER SCREWS LOOSE (ALL CYL)", "TIGHTENED SCREWS"], [100007, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL)", "TIGHTENED HOSE CLAMPS"], [100008, "#3 INTAKE IS LEAKING", "REMOVED & REPLACED GASKET"], [100009, "#2 INTAKE IS LEAKING", "REMOVED & REPLACED #2 INTAKE GASKET"], [100010, "#4 ROCKER COVER IS LEAKING", "REMOVED & REPLACED #4 ROCKER COVER GASKET"], [100011, "HOLDING SHORT OF RUNWAY, AFTER COMPLETION OF RUN UP, ENGINE", "PERFORMED ENGINE RUN UP, ADJUSTED IDLE & CLEANED SPARK"], [100012, "L/H REAR ENGINE BAFFLE CRACKED", "STOP DRILLED CRACK"], [100013, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYLS)", "TIGHTENED HOSE CLAMPS"], [100014, "#1, 2 & 3 ROCKER BOX COVER GASKETS LEAKING", "INSTALLED NEW ROCKER BOX COVER GASKETS"], [100015, "#2 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #2 ROCKER COVER GASKET"], [100016, "#1 & 3 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #1 & 3 ROCKER COVER GASKET"], [100017, "ROCKER BOX COVER SCREWS LOOSE", "TIGHTENED SCREWS"], [100018, "#1 ENGINE BAFFLE CRACKED", "FABRICATED PATCH OF LIKE MATERIAL & RIVETED IAW"], [100019, "#1 INTAKE GASKET LEAKING", "REPLACED W/ NEW GASKET"], [100020, "ROCKER COVER FOR CYL #1 IS LEAKING", "REPLACED ROCKER COVER"], [100021, "CYL #4 INTAKE LEAKING", "REPLACED GASKET. LEAK CHECK GOOD"], [100022, "#2 & 4 CYLINDER ROCKER COVER GASKETS LEAKING", "REMOVED & REPLACED ROCKER COVER GASKETS. CLEANED LEAKS"], [100023, "ROCKER BOX COVER SCREWS ARE LOOSE", "TIGHTENED SCREWS"], [100024, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYL)", "TIGHTENED HOSE CLAMPS"], [100025, "#1 INTAKE GASKET LEAKING", "REMOVED INTAKE TUBE, FOUND TUBE TO BE CRACKED. REMOVED"], [100026, "INDUCTION TUBE HOSE CLAMPS LOOSE (ALL CYLS)", "TIGHTENED HOSE CLAMPS"], [100027, "R/H MAG BLAST TUBE FELL OFF", "REMOVED R/H AFT BAFFLE TO FACILITATE REPAIR. FABRICATED"], [100028, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "INSPECTED CYL 1, 2 & 4 IAW  - CK'ED OK. REMOVED"], [100029, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "PERFORMED COMPRESSION CHECK, CYL #3 INDICATED ZERO PSI"], [100030, "ON START UP, ENGINE BEGAN TO RUN ROUGH. RAN ENGINE @ 1200 RP", "COMPLETED BAFFLE INSTALL, OIL FILLER TUBE, SPARK PLUGS"], [100031, "#4 ROCKER COVER GASKET LEAKING", "REPLACED GASKET"], [100032, "RIGHT ENG #4 AIR BAFFLE IS CRACKED", "REMOVED & REPLACED #4 AIR BAFFLE"], [100033, "R/H ENG FWD ALT ATTACH BOLT LOOSE", "SECURED ALT ATTACH BOLT & RESAFETIED"], [100034, "L/H ENGINE #4 AFT BAFFLE CRACKED IN MULTIPLE PLACES", "REPLACED BAFFLE ASSY"], [100035, "RIGHT ENG, ALL VALVE COVERS ARE LEAKING", "REMOVED & REPLACED ALL ROCKER GASKETS"], [100036, "L/H ENGINE ALL 4 ROCKER COVER GASKETS LEAKING", "REPLACED ALL ROCKER COVER GASKETS"], [100037, "L/H ENG #2 INTAKE LEAKING", "REMOVED TUBE, FOUND TO BE CRACKED. REMOVED TUBE FROM CO"], [100038, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "RAN A/C, MAGS CHECK GOOD. POWER & LEAK CHECK GOOD"], [100039, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REMOVED #3 CYL, DISCONNECTED FUEL DISTRIBUTOR LINE TO G"], [100040, "IN FLIGHT, ENGINE BECAME ROUGH. DISCOVERED RIGHT MAG INOP. E", "REASSEMBLED ENGINE, #3 CYL DRY TAPPET CLEARANCE CHECK G"], [100041, "#4 INTAKE LEAKING", "REMOVED & REPLACED #4 INTAKE GASKET"], [100042, "#3 ROCKER COVER GASKET LEAKING", "REMOVED & REPLACED #3 ROCKER COVER GASKET"], [100043, "TOP L/H BAFFLE HAS A CRACK", "STOP DRILLED CRACK"], [100044, " ...

# %%
from openai import OpenAI
client = OpenAI(api_key=open('openai-key.txt').read().strip())

prompt = """Given a set of aircraft maintenance problem descriptions, output a json object with an array of problem objects: {"problems":[ problem1, problem2, ... ]}
Each problem is an object with the following fields:
- "id" (id of problem, first number in description)
- "engine" (where the problem occurs. Single-letter string ("R" or "L") or null)
- "cylinders" (array of integers, where the problem occurs, e.g. [1])
- "part" (which single part causes the problem, e.g. "ENGINE BAFFLE")
- "problem" (ONE single word of what is going on, e.g. "LEAK", "FELL_OFF", "CRACK", "DAMAGE", "COMPRESSION", "NEED")
- "details" (more info that doesn't fit in the other fields, e.g. "BADLY")
The values of the fields MUST be substrings (spans) in the problem description.
All fields are optional except for "id".
If there is no very clear single part identified, don't fill in the field!
"""
from tqdm import tqdm
import json

out = []
for i in tqdm(range(0, len(df), 20)):
  lines = df.iloc[i:i+10][['ident', 'problem']].astype(str).apply(' '.join, axis=1)

  completion = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    temperature= 0,
    response_format={ "type": "json_object" },
    messages=[
      {"role": "system", "content": prompt},
      {"role": "user", "content": '\n'.join(lines)}
    ]
  )
  c = completion.choices[0].message.content
  with open(f'openai/{i}.json', 'w') as fw:
    print(c, file=fw)
  out += json.loads(c).get('problems', [])
out
# Out:
# 100%|██████████| 309/309 [36:32<00:00,  7.10s/it]
# [{'id': '100001',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ENGINE IDLE OVERRIDE',
#   'problem': 'KILLED',
#   'details': None},
#  {'id': '100002',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ENGINE IDLE OVERRIDE',
#   'problem': 'KILLED',
#   'details': None},
#  {'id': '100003',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ENGINE IDLE OVERRIDE',
#   'problem': 'KILLED',
#   'details': None},
#  {'id': '100004',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'ENGINE CHOKE',
#   'problem': 'LOSE',
#   'details': 'BRIEFLY LOSE POWER ON DEPARTURE. FULL THR'},
#  {'id': '100005',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100006',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': '(ALL CYL)'},
#  {'id': '100007',
#   'engine': None,
#   'cylinders': [],
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': '(ALL CYL)'},
#  {'id': '100008',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100009',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100010',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100021',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100022',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100023',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100024',
#   'engine': None,
#   'cylinders': None,
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100025',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100026',
#   'engine': None,
#   'cylinders': None,
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100027',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'BLAST TUBE',
#   'problem': 'FELL_OFF',
#   'details': None},
#  {'id': '100028',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE',
#   'problem': 'ROUGH',
#   'details': 'BEGAN TO RUN'},
#  {'id': '100029',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE',
#   'problem': 'ROUGH',
#   'details': 'BEGAN TO RUN'},
#  {'id': '100030',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE',
#   'problem': 'ROUGH',
#   'details': 'BEGAN TO RUN'},
#  {'id': '100041', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100042',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100043',
#   'engine': 'L',
#   'cylinders': [1],
#   'part': 'BAFFLE',
#   'problem': 'CRACK',
#   'details': 'HAS A'},
#  {'id': '100044',
#   'part': 'OIL DIPSTICK',
#   'problem': 'LOOSE',
#   'details': 'OIL STICK IS'},
#  {'id': '100045',
#   'cylinders': [3],
#   'part': 'BRAKE',
#   'problem': 'MISSING',
#   'details': 'SCREW'},
#  {'id': '100046',
#   'engine': 'R',
#   'part': 'BAFFLE SEALS',
#   'problem': 'TORN',
#   'details': 'ON R/H SIDE ARE'},
#  {'id': '100047',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100048',
#   'cylinders': [3],
#   'part': 'AFT BAFFLE BRACKET',
#   'problem': 'LOOSE'},
#  {'id': '100049',
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100050',
#   'cylinders': [1, 2, 6],
#   'part': 'COWL MOUNTS',
#   'problem': 'TORN'},
#  {'id': '100061', 'part': 'ROCKER COVER GASKET', 'problem': 'LEAKING'},
#  {'id': '100062', 'engine': 'ENGINE', 'problem': 'HIGH OIL PRESS'},
#  {'id': '100063', 'engine': 'ENGINE', 'problem': 'HIGH OIL PRESS'},
#  {'id': '100064', 'details': "COULDN'T START"},
#  {'id': '100065',
#   'part': 'VACUUM TUBE & OIL COOLER LINE',
#   'problem': 'RUBBING'},
#  {'id': '100066', 'details': 'IDLE @ 970 RPM'},
#  {'id': '100067', 'problem': 'FUEL PRESS'},
#  {'id': '100068',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKS'},
#  {'id': '100069',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100070',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100081',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKS',
#   'details': None},
#  {'id': '100082',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INTAKE',
#   'problem': 'LEAKS',
#   'details': None},
#  {'id': '100083',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE TUBE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100084',
#   'engine': None,
#   'cylinders': [3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100085',
#   'engine': None,
#   'cylinders': None,
#   'part': None,
#   'problem': 'START',
#   'details': 'WOULD NOT'},
#  {'id': '100086',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100087',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'BAFFLE',
#   'problem': 'PULLED',
#   'details': 'RIVET PULLED THROUGH'},
#  {'id': '100088',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100089',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INDUCTION TUBE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100090',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100101',
#   'engine': 'R',
#   'part': 'FUSELAGE',
#   'problem': 'LEAK',
#   'details': 'ENTIRE RIGHT SIDE'},
#  {'id': '100102',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'ENGINE BAFFLE',
#   'problem': 'MISSING',
#   'details': 'BOLT'},
#  {'id': '100103',
#   'engine': 'R',
#   'cylinders': [1, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100104',
#   'engine': 'L',
#   'cylinders': [1, 3],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100105', 'problem': 'DIED', 'details': 'DURING MAG CK'},
#  {'id': '100106',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': 'GASKET'},
#  {'id': '100107',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': 'GASKET'},
#  {'id': '100108',
#   'cylinders': [2, 4],
#   'part': 'OIL RETURN LINE',
#   'problem': 'LOOSE',
#   'details': 'CLAMPS'},
#  {'id': '100109',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100110',
#   'part': 'BAFFLE SEALS',
#   'problem': 'LOOSE',
#   'details': 'UNDER BOTH PROP GOVERNORS'},
#  {'id': '100121', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100122', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100123',
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100124',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100125',
#   'cylinders': [3],
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'SCREW IS MISSING'},
#  {'id': '100126',
#   'engine': 'R',
#   'part': 'FRONT BAFFLE SEAL',
#   'problem': 'LOOSE'},
#  {'id': '100127',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'TOP BACK L/H CORNER'},
#  {'id': '100128',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100129',
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100130', 'problem': 'RUNNING'},
#  {'id': '100141',
#   'engine': 'R',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': 'ARE'},
#  {'id': '100142',
#   'engine': 'R',
#   'cylinders': [3, 4],
#   'part': 'INTAKE TUBES',
#   'problem': 'LEAKING',
#   'details': 'ARE'},
#  {'id': '100143',
#   'engine': 'L',
#   'cylinders': [],
#   'part': 'LEFT AFT BAFFLE ANGLE BRACKET',
#   'problem': 'CRACKED',
#   'details': ''},
#  {'id': '100144',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': ''},
#  {'id': '100145',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER BOX COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100146',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100147',
#   'engine': None,
#   'cylinders': [],
#   'part': 'LEFT BRAKE LININGS',
#   'problem': 'WORN',
#   'details': 'OUT'},
#  {'id': '100148',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100149',
#   'engine': None,
#   'cylinders': [],
#   'part': None,
#   'problem': 'OVERSPEED',
#   'details': 'UP TO 3400 RPM @ TERMINATION OF AN AUTO'},
#  {'id': '100150',
#   'engine': None,
#   'cylinders': [],
#   'part': None,
#   'problem': 'OVERSPEED',
#   'details': 'UP TO 3400 RPM @ TERMINATION OF AN AUTO'},
#  {'id': '100161',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'FWD I/B BAFFLE',
#   'problem': 'CRACK',
#   'details': 'SMALL'},
#  {'id': '100162',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVERS',
#   'problem': 'LOOSE',
#   'details': 'ALL'},
#  {'id': '100163',
#   'engine': 'L',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100164',
#   'engine': 'R',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100165',
#   'engine': 'R',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100166',
#   'engine': 'R',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100167',
#   'engine': 'L',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100168',
#   'engine': 'R',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100169',
#   'engine': 'L',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100170',
#   'engine': 'R',
#   'cylinders': [],
#   'part': None,
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100181',
#   'engine': 'R',
#   'part': 'ENGINE',
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100182',
#   'engine': 'R',
#   'part': 'ENGINE',
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100183',
#   'engine': 'R',
#   'part': 'ENGINE',
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED TO FACILITATE REPAIR'},
#  {'id': '100184',
#   'part': 'ENGINE',
#   'problem': 'REMOVE',
#   'details': 'TO FACILITATE FIREWALL REPAIR'},
#  {'id': '100185',
#   'part': 'ENGINE',
#   'problem': 'REINSTALL',
#   'details': 'AFTER REPAIR TO FIREWALL'},
#  {'id': '100186',
#   'part': 'ENGINE',
#   'problem': 'REINSTALL',
#   'details': 'AFTER REPAIR TO FIREWALL'},
#  {'id': '100187',
#   'cylinders': [2, 4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100188', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100189',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100190', 'part': 'AFT BAFFLE', 'problem': 'SCREW LOOSE'},
#  {'id': '100201',
#   'engine': 'R',
#   'part': 'IGN LEAD',
#   'problem': 'LOOSE',
#   'details': 'ON SCAT TUBING'},
#  {'id': '100202',
#   'engine': 'L',
#   'part': 'ROCKER COVER SCREWS',
#   'problem': 'LOOSE'},
#  {'id': '100203',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '100204',
#   'engine': 'L',
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100205',
#   'engine': 'R',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100206', 'engine': 'R', 'problem': 'ROUGH'},
#  {'id': '100207', 'engine': 'R', 'problem': 'ROUGH'},
#  {'id': '100208',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '100209',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100210',
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100221',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100222',
#   'engine': None,
#   'cylinders': [],
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': 'ALL CYL'},
#  {'id': '100223',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': ''},
#  {'id': '100224',
#   'engine': 'L',
#   'cylinders': [1],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100225',
#   'engine': 'R',
#   'cylinders': [2, 1],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100226',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'FWD UPPER BAFFLE SEAL',
#   'problem': 'LOOSE',
#   'details': ''},
#  {'id': '100227',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100228',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': ''},
#  {'id': '100229',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100230',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100241',
#   'engine': 'R',
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': 'GASKETS'},
#  {'id': '100242',
#   'engine': None,
#   'part': 'AFT BAFFLE BRACKET',
#   'problem': 'SHEARED'},
#  {'id': '100243',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'WORN',
#   'details': 'THROUGH AT I/B CYLINDER WRAP'},
#  {'id': '100244',
#   'engine': 'R',
#   'part': 'BAFFLE',
#   'problem': 'CRACK',
#   'details': 'BY SCREW'},
#  {'id': '100245',
#   'engine': 'R',
#   'part': 'BAFFLE',
#   'problem': 'WORN',
#   'details': 'THROUGH FROM MUFFLER SHROUD'},
#  {'id': '100246',
#   'engine': 'R',
#   'part': 'BAFFLE',
#   'problem': 'WORN',
#   'details': 'THROUGH FROM MUFFLER SHROUD'},
#  {'id': '100247',
#   'engine': None,
#   'cylinders': [2, 3, 4],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100248',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'IN SEVERAL PLACES'},
#  {'id': '100249',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'IN SEVERAL PLACES'},
#  {'id': '100250',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'MISSING',
#   'details': 'SCREW'},
#  {'id': '100261',
#   'engine': None,
#   'cylinders': [1, 3],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100262',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': 'ALL CYL'},
#  {'id': '100263',
#   'engine': None,
#   'cylinders': None,
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': 'ALL CYL'},
#  {'id': '100264',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'AT CLAMP'},
#  {'id': '100265',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100266',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'RIVET PULLED THROUGH BAFFLE SEAL',
#   'problem': 'DAMAGE',
#   'details': '#1 CYL'},
#  {'id': '100267',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100268',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ENGINE I/B BAFFLE INTERCONNECT ROD',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '100269',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INDUCTION TUBE HOSE CLAMP',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '100270',
#   'engine': None,
#   'cylinders': [1, 2, 3],
#   'part': 'CYLINDER INTAKE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100281',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'AFT BAFFLE STIFFENER',
#   'problem': 'CRACKED',
#   'details': 'IS'},
#  {'id': '100282',
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100283',
#   'engine': 'R',
#   'part': 'FWD UPPER BAFFLE SEAL',
#   'problem': 'NEEDS',
#   'details': 'TO BE RESECURED'},
#  {'id': '100284', 'cylinders': [1], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100285',
#   'part': 'ROCKER COVERS',
#   'cylinders': [2, 3],
#   'problem': 'LEAKING'},
#  {'id': '100286', 'part': 'INDUCTION TUBE GASKET', 'problem': 'LEAKING'},
#  {'id': '100287',
#   'part': 'ROCKER BOX COVER GASKETS',
#   'cylinders': [2, 3],
#   'problem': 'LEAKING'},
#  {'id': '100288', 'problem': 'DURING'},
#  {'id': '100289',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'CAP SCREW'},
#  {'id': '100290',
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100301',
#   'engine': 'R',
#   'part': 'REAR BAFFLE',
#   'problem': 'LOOSE',
#   'details': 'MOUNTING SCREW'},
#  {'id': '100302',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'PLUG'},
#  {'id': '100303', 'cylinders': [3], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100304',
#   'part': 'ENGINE INSPECTION PANEL',
#   'problem': 'MISSING SCREW'},
#  {'id': '100305',
#   'cylinders': [1],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100306',
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100307',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100308',
#   'cylinders': [2, 3, 4],
#   'part': 'ROCKER BOX COVER',
#   'problem': 'LOOSE',
#   'details': 'SCREWS'},
#  {'id': '100309', 'part': 'STARTER RING GEAR', 'problem': 'MISSING TEETH'},
#  {'id': '100310',
#   'cylinders': [2, 4],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100321',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100322',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ENGINE BAFFLE',
#   'problem': 'BLOCKED',
#   'details': 'BLAST TUBE'},
#  {'id': '100323',
#   'engine': 'R',
#   'cylinders': [2, 3],
#   'part': None,
#   'problem': 'LEAKING',
#   'details': 'INTAKES'},
#  {'id': '100324',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100325',
#   'engine': 'L',
#   'cylinders': [1, 2, 4],
#   'part': None,
#   'problem': 'LEAKING',
#   'details': 'INTAKES'},
#  {'id': '100326',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100327',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'BAFFLE PLUG',
#   'problem': 'NEEDS',
#   'details': 'CHANGED'},
#  {'id': '100328',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100329',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'BOTTOM BAFFLE WIRE HOLDER',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '100330',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'CYL INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100341',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100342',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE BAFFLE BUTTONS',
#   'problem': 'WORN',
#   'details': None},
#  {'id': '100343',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100344',
#   'engine': None,
#   'cylinders': None,
#   'part': 'LOWER RIGHT BAFFLE SPRING',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '100345',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'BACK BAFFLE BRACKET',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100346',
#   'engine': None,
#   'cylinders': None,
#   'part': 'BAFFLE PLUGS',
#   'problem': 'BAD',
#   'details': 'BOTH'},
#  {'id': '100347',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100348',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100349',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'BACK BAFFLE SCREW',
#   'problem': 'MISSING',
#   'details': None},
#  {'id': '100350',
#   'engine': None,
#   'cylinders': [1, 3],
#   'part': 'ROCKER OIL RETURN LINES',
#   'problem': 'REQUIRES',
#   'details': 'SPIRAL WRAP'},
#  {'id': '100361',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'IS'},
#  {'id': '100362',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100363',
#   'engine': 'R',
#   'cylinders': [3, 2],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100364',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100365',
#   'engine': 'L',
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON'},
#  {'id': '100366',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100367',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INNER INTAKE PUSH ROD SEAL',
#   'problem': 'LEAKING'},
#  {'id': '100368',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100369',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100370',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'FWD PUSH ROD SEAL',
#   'problem': 'LEAKING',
#   'details': '@ ENGINE ON'},
#  {'id': '100381',
#   'engine': None,
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100382',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'MISSING',
#   'details': 'SCREW'},
#  {'id': '100383',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100384',
#   'engine': None,
#   'cylinders': None,
#   'part': None,
#   'problem': 'ROUGH',
#   'details': 'SUSPECT STUCK VALVE'},
#  {'id': '100385',
#   'engine': None,
#   'cylinders': None,
#   'part': None,
#   'problem': 'ROUGH',
#   'details': 'SUSPECT STUCK VALVE'},
#  {'id': '100386',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'PUSH ROD TUBE',
#   'problem': 'LEAKING',
#   'details': '@ ENGINE'},
#  {'id': '100387',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE TUBE',
#   'problem': 'LEAKING',
#   'details': 'AT SUMP CONNECTOR HOSE'},
#  {'id': '100388',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE MOUNT',
#   'problem': 'SHEARED',
#   'details': 'RIVETS'},
#  {'id': '100389',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'BAFFLE SEAL',
#   'problem': 'NEEDS',
#   'details': 'TO BE RESECURED'},
#  {'id': '100390',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKS',
#   'details': None},
#  {'id': '100401',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100402',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100403',
#   'engine': None,
#   'cylinders': None,
#   'part': 'OIL RETURN LINE CLAMPS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100404',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'SAFETY BAFFLE BOLTS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100405',
#   'engine': None,
#   'cylinders': [1, 3],
#   'part': 'FUEL INJ LINES STANDOFF',
#   'problem': 'LOOSE',
#   'details': 'BY OIL FILLER TUBE'},
#  {'id': '100406',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100407',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100408',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100409',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100410',
#   'engine': 'R',
#   'cylinders': [2, 4],
#   'part': 'ROCKER OIL RETURN LINES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100421',
#   'engine': None,
#   'cylinders': [],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100422',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100423',
#   'engine': None,
#   'cylinders': [],
#   'part': '',
#   'problem': 'TIMED',
#   'details': 'OUT'},
#  {'id': '100424',
#   'engine': None,
#   'cylinders': [],
#   'part': '',
#   'problem': 'TIMED',
#   'details': 'OUT'},
#  {'id': '100425',
#   'engine': None,
#   'cylinders': [],
#   'part': '',
#   'problem': 'TIMED',
#   'details': 'OUT'},
#  {'id': '100426',
#   'engine': None,
#   'cylinders': [],
#   'part': '',
#   'problem': 'TIMED',
#   'details': 'OUT'},
#  {'id': '100427',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100428',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'UPPER BAFFLE',
#   'problem': 'ENLARGED',
#   'details': ''},
#  {'id': '100429',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'INNER CYL BAFFLE TIE ROD',
#   'problem': 'INSTALLED',
#   'details': 'INCORRECTLY'},
#  {'id': '100430',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100441',
#   'engine': 'L',
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON L/H ENGINE'},
#  {'id': '100442',
#   'engine': 'R',
#   'cylinders': [2, 3, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '100443', 'part': 'INDUCTION TUBE GASKET', 'problem': 'LEAKING'},
#  {'id': '100444',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'SCREW & NUT ON BAFFLE BY OIL FILL TUBE'},
#  {'id': '100445',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': '#3 BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'BY UPPER #1 BAFFLE ATTACHMENT'},
#  {'id': '100446',
#   'cylinders': [2],
#   'part': '#2 CYLINDER INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100447', 'part': '#1 ROCKER COVER GASKET', 'problem': 'LEAKING'},
#  {'id': '100448', 'cylinders': [3], 'part': '#3 INTAKE', 'problem': 'LEAKING'},
#  {'id': '100449',
#   'engine': 'L',
#   'part': 'BACK TOP BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100450', 'problem': 'IDLE'},
#  {'id': '100461', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100462',
#   'engine': 'L',
#   'part': 'BAFFLE PLUG',
#   'problem': 'NEEDS',
#   'details': 'TO BE REPLACED'},
#  {'id': '100463',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100464',
#   'engine': 'R',
#   'cylinders': [1],
#   'part': 'BOTTOM BAFFLE WIRE SPRING',
#   'problem': 'BROKEN'},
#  {'id': '100465',
#   'part': 'AFT BAFFLE BRACKET',
#   'problem': 'SHEARED',
#   'details': 'RIVETS'},
#  {'id': '100466',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100467',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100468', 'cylinders': [3], 'part': 'BAFFLE PLUG', 'problem': 'WORN'},
#  {'id': '100469',
#   'cylinders': [1, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '100470', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100481', 'part': 'ROCKER COVERS', 'problem': 'LEAKING'},
#  {'id': '100482', 'cylinders': [3], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100483',
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': '(ALL CYLS)'},
#  {'id': '100484',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100485', 'engine': 'L', 'part': 'INTAKES', 'problem': 'LEAKING'},
#  {'id': '100486',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'TAB HAS BROKEN RIVETS, NEAR OIL FILLER TUBE'},
#  {'id': '100487',
#   'cylinders': [4],
#   'part': 'AFT BAFFLE ATTACH PLATE',
#   'problem': 'BROKEN'},
#  {'id': '100488',
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'TAB HAS BROKEN RIVETS, NEAR OIL FILLER TUBE'},
#  {'id': '100489',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100490',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100501',
#   'engine': 'L',
#   'part': 'ENGINE BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100502', 'part': 'ROCKER COVER GASKETS', 'problem': 'LEAKING'},
#  {'id': '100503',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100504',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100505', 'cylinders': [3], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100506',
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100507',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100508',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKS'},
#  {'id': '100509',
#   'cylinders': [2, 3],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100510',
#   'cylinders': [3, 4],
#   'part': 'SIDE BAFFLE PLUGS',
#   'problem': 'BROKEN'},
#  {'id': '100521',
#   'engine': 'L',
#   'cylinders': [1],
#   'part': 'OIL COOLER BAFFLING',
#   'problem': 'CRACKED',
#   'details': 'IN LWR I/B CORNER'},
#  {'id': '100522',
#   'engine': 'R',
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'PAST STOP DRILLED HOLES'},
#  {'id': '100523', 'problem': 'DISCHARGE', 'details': 'BATTERY STILL SHOWING'},
#  {'id': '100524',
#   'cylinders': [3],
#   'part': 'OIL RETURN LINE',
#   'problem': 'LEAKING',
#   'details': 'ON RUBBER HOSE SECTION'},
#  {'id': '100525',
#   'cylinders': [2, 4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100526',
#   'cylinders': [1, 2, 3],
#   'part': 'COWL SHOCK MOUNTS',
#   'problem': 'TORN'},
#  {'id': '100527',
#   'cylinders': [1, 3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': 'GASKETS'},
#  {'id': '100528',
#   'part': 'ROCKER BOX COVER',
#   'problem': 'LOOSE',
#   'details': 'SCREWS'},
#  {'id': '100529',
#   'part': 'ROCKER BOX COVER',
#   'problem': 'LOOSE',
#   'details': 'SCREWS'},
#  {'id': '100530',
#   'part': 'INDUCTION TUBE HOSE CLAMPS',
#   'problem': 'LOOSE',
#   'details': '(ALL CYL)'},
#  {'id': '100541',
#   'part': 'ROCKER COVER',
#   'problem': 'LOOSE',
#   'details': 'ARE'},
#  {'id': '100542',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100543',
#   'cylinders': [2],
#   'problem': 'MISSING',
#   'details': 'ON RUN UP (RUNS ROUGH)'},
#  {'id': '100544',
#   'cylinders': [2],
#   'problem': 'MISSING',
#   'details': 'ON RUN UP (RUNS ROUGH)'},
#  {'id': '100545',
#   'cylinders': [2],
#   'problem': 'MISSING',
#   'details': 'ON RUN UP (RUNS ROUGH)'},
#  {'id': '100546',
#   'cylinders': [2],
#   'problem': 'MISSING',
#   'details': 'ON RUN UP (RUNS ROUGH)'},
#  {'id': '100547',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKS'},
#  {'id': '100548',
#   'engine': 'ENGINE',
#   'part': 'BAFFLE PLUG',
#   'problem': 'MISSING'},
#  {'id': '100549',
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '100550',
#   'cylinders': [1, 2],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON L/H ENGINE'},
#  {'id': '100561',
#   'engine': 'R',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '100562', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100563',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100564', 'cylinders': [3], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100565',
#   'cylinders': [3],
#   'part': 'INTAKE TUBE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100566',
#   'cylinders': [1],
#   'part': 'OIL RETURN LINE',
#   'problem': 'CHAFING'},
#  {'id': '100567', 'engine': 'R', 'part': 'OIL FILL TUBE', 'problem': 'LOOSE'},
#  {'id': '100568',
#   'part': 'ENGINE BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'PLUG TABS'},
#  {'id': '100569',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100570',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100581', 'part': 'INTAKE GASKET', 'problem': 'LEAKING'},
#  {'id': '100582', 'part': 'ROCKER COVER GASKET', 'problem': 'LEAKING'},
#  {'id': '100583', 'part': 'INTAKE GASKET', 'problem': 'LEAKING'},
#  {'id': '100584', 'part': 'ROCKER COVER GASKET', 'problem': 'LEAKING'},
#  {'id': '100585',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'FRONT BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100586', 'part': 'ROCKER COVERS', 'problem': 'LOOSE'},
#  {'id': '100587',
#   'cylinders': [4],
#   'part': 'CYLINDER INTAKE TUBE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100588',
#   'engine': 'R',
#   'cylinders': [1],
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '100589',
#   'engine': 'L',
#   'cylinders': [2, 3, 4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '100590', 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100601',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100602',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100603',
#   'engine': None,
#   'cylinders': [],
#   'part': 'THROTTLE LINKAGE DOG BONE',
#   'problem': 'LOOSE',
#   'details': 'BEARING'},
#  {'id': '100604',
#   'engine': None,
#   'cylinders': [],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100605',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100606',
#   'engine': 'L',
#   'cylinders': [1, 2, 3, 4],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100607',
#   'engine': 'R',
#   'cylinders': [1, 3, 4],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100608',
#   'engine': None,
#   'cylinders': [],
#   'part': 'BAFFLE',
#   'problem': 'CRACK',
#   'details': 'CORNER'},
#  {'id': '100609',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100610',
#   'engine': None,
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100621',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'ENGINE BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'RIVETS'},
#  {'id': '100622',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100623',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER BOX COVER',
#   'problem': 'LOOSE',
#   'details': 'SCREWS'},
#  {'id': '100624',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INDUCTION TUBE',
#   'problem': 'LEAKING',
#   'details': 'GASKET'},
#  {'id': '100625',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'GASKET'},
#  {'id': '100626',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100627',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER',
#   'problem': 'LEAKING',
#   'details': 'GASKET'},
#  {'id': '100628',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'BAFFLE PLUGS',
#   'problem': 'BROKEN',
#   'details': 'SEVERAL BROKEN PRONGS'},
#  {'id': '100629',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKS',
#   'details': 'GASKET'},
#  {'id': '100630',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': 'CYL #2'},
#  {'id': '100641',
#   'engine': 'R',
#   'cylinders': [2, 4],
#   'part': 'INDUCTION TUBE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100642',
#   'engine': 'L',
#   'cylinders': [2, 3, 4],
#   'part': 'INDUCTION TUBE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100643',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ROCKER BOX COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100644',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ENG BAFFLING',
#   'problem': 'CRACKED',
#   'details': 'R/H SIDE, ABOVE #1 CYLINDER'},
#  {'id': '100645',
#   'engine': None,
#   'cylinders': None,
#   'part': 'FIREWALL',
#   'problem': 'CRACKED',
#   'details': 'BY BATTERY BOX'},
#  {'id': '100646',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ENG BAFFLING',
#   'problem': 'CRACKED',
#   'details': 'R/H SIDE, ABOVE #1 CYLINDER'},
#  {'id': '100647',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100648',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100649',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100650',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'EXHAUST I/B PUSH ROD SEAL',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100661',
#   'part': 'FWD BAFFLE',
#   'problem': 'WORN',
#   'details': 'THROUGH'},
#  {'id': '100662', 'part': 'INTAKE GASKET', 'problem': 'LEAKING'},
#  {'id': '100663', 'engine': 'R', 'part': 'BACK BAFFLE', 'problem': 'MISSING'},
#  {'id': '100664', 'part': 'INTAKE GASKET', 'problem': 'LEAKING'},
#  {'id': '100665',
#   'cylinders': [1, 3],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100666',
#   'engine': 'R',
#   'cylinders': [2, 3],
#   'part': 'INDUCTION',
#   'problem': 'LEAKING'},
#  {'id': '100667',
#   'cylinders': [3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'BROKEN'},
#  {'id': '100668',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'TORN'},
#  {'id': '100669',
#   'cylinders': [1, 3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'TORN'},
#  {'id': '100670', 'details': "COULDN'T REMOVE DIPSTICK"},
#  {'id': '100681',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100682',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ROCKER BOX COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': None},
#  {'id': '100683',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER BOX COVER GASKET',
#   'problem': 'LEAKS',
#   'details': None},
#  {'id': '100684',
#   'engine': None,
#   'cylinders': [1, 3],
#   'part': 'CYLINDER LOWER BAFFLE',
#   'problem': 'CRACKED',
#   'details': None},
#  {'id': '100685',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'INTAKE TUBE',
#   'problem': 'CANNED',
#   'details': None},
#  {'id': '100686',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100687',
#   'engine': 'R',
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100688',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100689',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'SPLIT',
#   'details': None},
#  {'id': '100690',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INDUCATION TUBE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100701',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100702',
#   'engine': 'L',
#   'cylinders': [2, 3, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100703', 'part': 'BAFFLE SEALS', 'problem': 'NEED'},
#  {'id': '100704',
#   'engine': 'R',
#   'cylinders': [2, 3, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '100705', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100706',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100707', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100708', 'engine': 'R', 'part': 'COWL SEAL', 'problem': 'LOOSE'},
#  {'id': '100709',
#   'engine': 'R',
#   'part': 'AFT BAFFLE',
#   'problem': 'MISSING',
#   'details': 'HARDWARE'},
#  {'id': '100710',
#   'engine': 'R',
#   'part': 'AFT BAFFLE',
#   'problem': 'MISSING',
#   'details': 'HARDWARE'},
#  {'id': '100721',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'BAFFLE BRACKET',
#   'problem': 'SHEARED',
#   'details': 'RIVETS'},
#  {'id': '100722',
#   'engine': None,
#   'cylinders': [],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100723',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'BAFFLE BACK BRACKET',
#   'problem': 'SHEARED OFF',
#   'details': 'RIVET HEAD'},
#  {'id': '100724',
#   'engine': None,
#   'cylinders': [],
#   'part': 'AFT BAFFLE BRACKET',
#   'problem': 'MISSING',
#   'details': 'SCREW'},
#  {'id': '100725',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'SCREW'},
#  {'id': '100726',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'BAFFLE',
#   'problem': 'CRACKED',
#   'details': ''},
#  {'id': '100727',
#   'engine': None,
#   'cylinders': [],
#   'part': 'BAFFLE PLUGS',
#   'problem': 'WORN OUT',
#   'details': ''},
#  {'id': '100728',
#   'engine': None,
#   'cylinders': [],
#   'part': 'FUEL LINE',
#   'problem': 'NEEDED',
#   'details': 'STAND OFF'},
#  {'id': '100729',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'BAFFLE',
#   'problem': 'MISSING RIVET',
#   'details': 'ON AFT SUPPORT BRACKET'},
#  {'id': '100730',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100741', 'problem': 'START'},
#  {'id': '100742',
#   'engine': 'R',
#   'cylinders': [3, 4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '100743',
#   'engine': 'L',
#   'cylinders': [3, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON L/H ENGINE'},
#  {'id': '100744',
#   'engine': 'R',
#   'part': 'ENGINE BAFFLE',
#   'problem': 'MISSING',
#   'details': 'HARDWARE'},
#  {'id': '100745', 'engine': 'L', 'part': 'FRONT BAFFLE', 'problem': 'CRACK'},
#  {'id': '100746',
#   'engine': 'R',
#   'part': 'BACK BAFFLE',
#   'problem': 'CRACK',
#   'details': 'BRACKET IS MISSING A RIVET'},
#  {'id': '100747',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100748',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100749',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100750',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'SIDE BAFFLE SEAL',
#   'problem': 'TORN'},
#  {'id': '100761',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'ON L/H ENG'},
#  {'id': '100762',
#   'engine': None,
#   'cylinders': None,
#   'part': None,
#   'problem': 'ROUGH',
#   'details': 'CLIMB OUT 1 OR BOTH ENGINES RAN VERY'},
#  {'id': '100763',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100764',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE HOIST LOOP',
#   'problem': 'LOOSE',
#   'details': 'FWD'},
#  {'id': '100765',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100766',
#   'engine': None,
#   'cylinders': [1, 2, 3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100767',
#   'engine': None,
#   'cylinders': None,
#   'part': 'OIL COOLER',
#   'problem': 'NEEDS',
#   'details': 'TO BE REPLACED'},
#  {'id': '100768',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INDUCTION TUBE HOSE CLAMP',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '100769',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100770',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'INDUCTION TUBE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100781',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100782',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100783',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100784',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'BAFFLE',
#   'problem': 'CRACKED',
#   'details': ''},
#  {'id': '100785',
#   'engine': 'R',
#   'cylinders': [],
#   'part': 'ENGINE BAFFLE',
#   'problem': 'CRACKED',
#   'details': ''},
#  {'id': '100786',
#   'engine': None,
#   'cylinders': [],
#   'part': 'BATTERY & ENGINE OVERBOARD VENT TUBES',
#   'problem': 'CHAFED',
#   'details': ''},
#  {'id': '100787',
#   'engine': None,
#   'cylinders': [],
#   'part': 'ROCKER COVER SCREWS',
#   'problem': 'LOOSE',
#   'details': ''},
#  {'id': '100788',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'ROCKER SHAFT PLUG',
#   'problem': 'WORN',
#   'details': ''},
#  {'id': '100789',
#   'engine': 'R',
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100790',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': ''},
#  {'id': '100801',
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '100802',
#   'engine': 'L',
#   'part': 'ENGINE BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '100803', 'part': 'EGT WIRE PROBE STANDOFFS', 'problem': 'BROKEN'},
#  {'id': '100804', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '100805',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100806', 'part': 'FRONT ENGINE BAFFLE SCREWS', 'problem': 'CHAFING'},
#  {'id': '100807', 'part': 'LOWER OIL COOLER LINE', 'problem': 'REPOSITIONED'},
#  {'id': '100808',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100809',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '100810',
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '100821',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100822',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100823',
#   'engine': None,
#   'cylinders': None,
#   'part': 'RUDDER COVERS',
#   'problem': 'CRACKED',
#   'details': None},
#  {'id': '100824',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INDUCTION TUBE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100825',
#   'engine': None,
#   'cylinders': None,
#   'part': 'FRONT BAFFLE',
#   'problem': 'CRACK',
#   'details': 'AROUND MUFFLER SHROUD'},
#  {'id': '100826',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100827',
#   'engine': None,
#   'cylinders': None,
#   'part': 'FWD BAFFLE',
#   'problem': 'WORN',
#   'details': 'THROUGH'},
#  {'id': '100828',
#   'engine': 'L',
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100829',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100830',
#   'engine': 'L',
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100841',
#   'engine': None,
#   'cylinders': None,
#   'part': 'FWD BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'UNDER HEAT SHROUD AIR INTAKE'},
#  {'id': '100842',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'R/H SIDE'},
#  {'id': '100843',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '100844',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'ROCKER COVER',
#   'problem': 'LOOSE',
#   'details': 'SCREWS'},
#  {'id': '100845',
#   'engine': 'R',
# ...
#  {'id': '101706',
#   'engine': 'R',
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'BY ENGINE MOUNT BOLT HOLE'},
#  {'id': '101707', 'part': 'BAFFLE BRACKET', 'problem': 'CRACKED'},
#  {'id': '101708', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101709',
#   'engine': 'ALL ENG',
#   'part': 'ROCKER COVER SCREWS',
#   'problem': 'LOOSE'},
#  {'id': '101710', 'problem': 'STARTER'},
#  {'id': '101721',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'EXHAUST VALVE',
#   'problem': 'BAD',
#   'details': 'HAS'},
#  {'id': '101722',
#   'engine': 'L',
#   'cylinders': [1],
#   'part': 'FIRST STAGE COMPRESSOR ROTOR',
#   'problem': 'COMPRESSOR',
#   'details': 'HAS 1'},
#  {'id': '101723',
#   'cylinders': [2],
#   'part': 'TOP BAFFLE SEAL',
#   'problem': 'LOOSE'},
#  {'id': '101724',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101725',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101726',
#   'cylinders': [1],
#   'part': 'INTAKE TUBE',
#   'problem': 'LEAKING',
#   'details': 'AROUND OIL SUMP CONNECTION AREA'},
#  {'id': '101727',
#   'cylinders': [1],
#   'part': 'INTAKE TUBE',
#   'problem': 'LEAKING',
#   'details': 'AROUND OIL SUMP CONNECTION AREA'},
#  {'id': '101728',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101729',
#   'cylinders': [3, 4],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101730',
#   'problem': 'OVERSPEED',
#   'details': 'TO 2730 RPM FOR 1 SECOND'},
#  {'id': '101741',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER OIL RETURN LINE',
#   'problem': 'CHAFING',
#   'details': None},
#  {'id': '101742',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER OIL RETURN LINE',
#   'problem': 'CHAFING',
#   'details': None},
#  {'id': '101743',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101744',
#   'engine': None,
#   'cylinders': None,
#   'part': 'BAFFLE BUTTON PLUG',
#   'problem': 'WORN',
#   'details': None},
#  {'id': '101745',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'TORN',
#   'details': None},
#  {'id': '101746',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101747',
#   'engine': None,
#   'cylinders': None,
#   'part': 'ENGINE BAFFLE SEAL',
#   'problem': 'HOLES',
#   'details': 'FWD BOTTOM'},
#  {'id': '101748',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101749',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101750',
#   'engine': None,
#   'cylinders': None,
#   'part': 'OIL COOLER LOWER BAFFLE SEAL',
#   'problem': 'MISSING',
#   'details': None},
#  {'id': '101761',
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101762',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101763', 'cylinders': [3], 'problem': 'LEAKING'},
#  {'id': '101764',
#   'engine': 'R',
#   'part': 'BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'SAFETY WIRE'},
#  {'id': '101765',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'BUTTON PLUG IS'},
#  {'id': '101766', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101767',
#   'cylinders': [1, 3, 4],
#   'part': 'ROCKER COVERS',
#   'problem': 'LEAKING'},
#  {'id': '101768',
#   'part': 'CASE HALVES',
#   'problem': 'LEAKING',
#   'details': 'BOTTOM FWD PORTION'},
#  {'id': '101769', 'cylinders': [1], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101770',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'I/B BAFFLE SPRING IS BRKOEN'},
#  {'id': '101781',
#   'part': 'PARTICLE SEPERATOR',
#   'problem': 'GRASS',
#   'details': 'IN IT'},
#  {'id': '101782', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101783',
#   'engine': 'L',
#   'part': 'LOWER ENGINE BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '101784',
#   'engine': 'R',
#   'part': 'ENGINE SIDE BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '101785',
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101786',
#   'part': 'FORWARD BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'NEAR ALTERNATOR'},
#  {'id': '101787', 'part': 'ENG BAFFLE BUTTONS', 'problem': 'WORN'},
#  {'id': '101788',
#   'part': 'ROCKER COVER SCREWS',
#   'problem': 'LOOSE & 1 MISSING'},
#  {'id': '101789', 'cylinders': [4], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101790',
#   'engine': None,
#   'problem': 'ROUGH',
#   'details': 'DURING CRUISE, ENGINE BECAME INCREDIBLY'},
#  {'id': '101801',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'MISSING',
#   'details': 'LOCK TABS'},
#  {'id': '101802',
#   'cylinders': [3],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '101803', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKING'},
#  {'id': '101804',
#   'engine': 'R',
#   'part': 'ENGINE BAFFLE SEAL',
#   'problem': 'LOOSE'},
#  {'id': '101805',
#   'cylinders': [2],
#   'part': 'INDUCTION TUBE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101806',
#   'engine': 'R',
#   'part': 'ENGINE BAFFLE SUPPORT BRACKET',
#   'problem': 'BROKEN',
#   'details': 'RIVETS'},
#  {'id': '101807',
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '101808',
#   'cylinders': [3],
#   'engine': 'R',
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '101809',
#   'cylinders': [2, 3, 4],
#   'engine': 'L',
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '101810',
#   'engine': 'L',
#   'part': 'BAFFLE SEAL',
#   'problem': 'LOOSE',
#   'details': 'LOWER FWD'},
#  {'id': '101821',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101822',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101823',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101824',
#   'engine': None,
#   'cylinders': [3, 2],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': 'ARE'},
#  {'id': '101825',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': None},
#  {'id': '101826',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ENGINE BAFFLE PLUG',
#   'problem': 'DAMAGED',
#   'details': None},
#  {'id': '101827',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101828',
#   'engine': None,
#   'cylinders': [2, 3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101829',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101830',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101841',
#   'part': 'ROCKER COVER',
#   'problem': 'MISSING',
#   'details': 'ON #2'},
#  {'id': '101842',
#   'cylinders': [3, 4],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '101843',
#   'cylinders': [3, 1],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101844',
#   'part': 'FWD BAFFLE',
#   'problem': 'CRACK',
#   'details': 'IN FWD BAFFLE CENTER'},
#  {'id': '101845', 'part': 'FWD LOWER BAFFLE SEAL', 'problem': 'LOOSE'},
#  {'id': '101846',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101847',
#   'cylinders': [1, 2],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101848',
#   'engine': 'L',
#   'part': 'ENGINE BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'FROM HEAT AIR INTAKE DOWN'},
#  {'id': '101849',
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101850',
#   'cylinders': [2],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101861',
#   'cylinders': [3, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101862',
#   'cylinders': [3],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101863',
#   'cylinders': [1],
#   'part': 'SIDE BAFFLE',
#   'problem': 'CRACKED'},
#  {'id': '101864',
#   'cylinders': [3, 4],
#   'part': 'ROCKER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101865',
#   'cylinders': [4],
#   'part': 'INTAKE TUBE',
#   'problem': 'LEAKING'},
#  {'id': '101866',
#   'cylinders': [3],
#   'engine': 'R',
#   'part': 'INTAKE',
#   'problem': 'LEAKING'},
#  {'id': '101867',
#   'cylinders': [2],
#   'engine': 'L',
#   'problem': 'MISSING',
#   'details': 'HARDWARE'},
#  {'id': '101868',
#   'cylinders': [2, 4],
#   'engine': 'R',
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '101869', 'part': 'MUFFLER HEAT MUFF', 'problem': 'CRACKED'},
#  {'id': '101870', 'problem': 'FAILS'},
#  {'id': '101882',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'CRACKED',
#   'details': None},
#  {'id': '101883',
#   'engine': None,
#   'cylinders': [2, 3],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101884',
#   'engine': None,
#   'cylinders': None,
#   'part': 'VALVE COVERS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101885',
#   'engine': 'L',
#   'cylinders': None,
#   'part': 'ENGINE OIL COOLER TO ENGINE LIFTING EYE BRACKET',
#   'problem': 'BROKEN',
#   'details': None},
#  {'id': '101886',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'ENGINE LIFTING EYE BOLT',
#   'problem': 'LEAKING',
#   'details': 'OIL'},
#  {'id': '101887',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101888',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'CYL BAFFLE BRACE',
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED FOR CAN O'},
#  {'id': '101889',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'CYL BAFFLE BRACE',
#   'problem': 'NEEDS',
#   'details': 'TO BE REMOVED FOR CAN O'},
#  {'id': '101901',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101902',
#   'engine': None,
#   'cylinders': None,
#   'part': None,
#   'problem': 'RPM',
#   'details': 'OF 2720'},
#  {'id': '101903',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101904',
#   'engine': None,
#   'cylinders': None,
#   'part': 'CRANKSHAFT SEAL',
#   'problem': 'LEAKING',
#   'details': 'APPEARS TO BE'},
#  {'id': '101905',
#   'engine': None,
#   'cylinders': None,
#   'part': 'CRANKSHAFT SEAL',
#   'problem': 'LEAKING',
#   'details': 'APPEARS TO BE'},
#  {'id': '101906',
#   'engine': None,
#   'cylinders': None,
#   'part': 'CRANKSHAFT SEAL',
#   'problem': 'LEAKING',
#   'details': 'APPEARS TO BE'},
#  {'id': '101907',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'INTAKE GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101908',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'AFT BAFFLE',
#   'problem': 'LOOSE',
#   'details': 'SCREW IS TIGHT, BUT'},
#  {'id': '101909',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101910',
#   'engine': None,
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101921',
#   'cylinders': [1, 2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING'},
#  {'id': '101922',
#   'cylinders': [4],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101923',
#   'engine': 'L',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER SCREWS',
#   'problem': 'LOOSE'},
#  {'id': '101924',
#   'engine': 'L',
#   'part': 'BAFFLE',
#   'problem': 'ELONGATED',
#   'details': 'PLUG HOLE IS ELONGATED'},
#  {'id': '101925',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101926',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101927',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING'},
#  {'id': '101928', 'cylinders': [2], 'part': 'INTAKE', 'problem': 'LEAKS'},
#  {'id': '101929',
#   'cylinders': [1],
#   'problem': 'COMPRESSION',
#   'details': 'HAS LOW COMPRESSION'},
#  {'id': '101930',
#   'cylinders': [1],
#   'problem': 'COMPRESSION',
#   'details': 'HAS LOW COMPRESSION'},
#  {'id': '101941',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'ENGINE BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'BAFFLING'},
#  {'id': '101942',
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101943',
#   'engine': 'L',
#   'part': 'COOLING BAFFLE',
#   'problem': 'BROKEN',
#   'details': 'CONNECTING ROD'},
#  {'id': '101944',
#   'engine': 'R',
#   'cylinders': [1],
#   'part': 'CYL COOLING BAFFLE',
#   'problem': 'CONTACTING',
#   'details': 'OIL RETURN LINE'},
#  {'id': '101945',
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101946',
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101947', 'part': 'FWD CENTER ENG BAFFLE', 'problem': 'CRACKED'},
#  {'id': '101948',
#   'cylinders': [2, 3, 4],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  {'id': '101949',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING'},
#  {'id': '101950',
#   'engine': 'R',
#   'part': 'REAR BAFFLE',
#   'problem': 'MISSING',
#   'details': 'HARDWARE'},
#  {'id': '101961',
#   'engine': 'L',
#   'cylinders': [],
#   'part': 'ENG BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'AT CORNER'},
#  {'id': '101962',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101963',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'ROCKER COVER SCREW',
#   'problem': "WON'T TIGHTEN",
#   'details': None},
#  {'id': '101964',
#   'engine': 'L',
#   'cylinders': [2, 3],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101965',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'INTAKE TUBE',
#   'problem': 'DAMAGED',
#   'details': None},
#  {'id': '101966',
#   'engine': 'L',
#   'cylinders': [4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101967',
#   'engine': 'L',
#   'cylinders': [3],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'ALONG W/ #2'},
#  {'id': '101968',
#   'engine': None,
#   'cylinders': [2, 3, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101969',
#   'engine': None,
#   'cylinders': [2],
#   'part': 'INTAKE GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101970',
#   'engine': None,
#   'cylinders': [1],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101981',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101982',
#   'engine': 'R',
#   'cylinders': None,
#   'part': 'AFT COOLING BAFFLING',
#   'problem': 'SHEARED',
#   'details': 'RIVETS'},
#  {'id': '101983',
#   'engine': None,
#   'cylinders': [3],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101984',
#   'engine': None,
#   'cylinders': None,
#   'part': 'BAFFLE PLUGS',
#   'problem': 'BROKEN',
#   'details': 'FINGERS'},
#  {'id': '101985',
#   'engine': None,
#   'cylinders': [2, 4],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101986',
#   'engine': None,
#   'cylinders': [4],
#   'part': 'BAFFLE',
#   'problem': 'CRACKED',
#   'details': 'IN FRONT OF OIL COOLER'},
#  {'id': '101987',
#   'engine': None,
#   'cylinders': [2, 3],
#   'part': 'ROCKER COVER GASKETS',
#   'problem': 'LEAKING',
#   'details': None},
#  {'id': '101988',
#   'engine': 'R',
#   'cylinders': [4],
#   'part': 'INTAKE',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '101989',
#   'engine': 'L',
#   'cylinders': [2, 4],
#   'part': 'INTAKES',
#   'problem': 'LEAKING',
#   'details': 'ON L/H ENGINE'},
#  {'id': '101990',
#   'engine': 'R',
#   'cylinders': [2],
#   'part': 'ROCKER COVER',
#   'problem': 'LEAKING',
#   'details': 'ON R/H ENGINE'},
#  {'id': '102001',
#   'cylinders': [1],
#   'part': 'ROCKER COVER GASKET',
#   'problem': 'LEAKING'},
#  ...]

# %%
p = pd.DataFrame.from_records(out)
p.to_csv('problem_extractions_chatgpt_2.csv', index=None)
show(p)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_24cfce3f_96c8_49f3_94bd_8fcf3437e790" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#       <th>engine</th>
#       <th>cylinders</th>
#       <th>part</th>
#       <th>problem</th>
#       <th>details</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     $(document).ready(function () {
#         document.querySelectorAll("#itables_24cfce3f_96c8_49f3_94bd_8fcf3437e790:not(.dataTable)").forEach(table => {
#             // Define the table data
#             const data = [["100001", "None", "[]", "ENGINE IDLE OVERRIDE", "KILLED", "None"], ["100002", "None", "[]", "ENGINE IDLE OVERRIDE", "KILLED", "None"], ["100003", "None", "[]", "ENGINE IDLE OVERRIDE", "KILLED", "None"], ["100004", "R", "[]", "ENGINE CHOKE", "LOSE", "BRIEFLY LOSE POWER ON DEPARTURE. FULL THR"], ["100005", "None", "[2, 4]", "ROCKER COVER GASKETS", "LEAKING", "None"], ["100006", "None", "[]", "ROCKER BOX COVER SCREWS", "LOOSE", "(ALL CYL)"], ["100007", "None", "[]", "INDUCTION TUBE HOSE CLAMPS", "LOOSE", "(ALL CYL)"], ["100008", "None", "[3]", "INTAKE", "LEAKING", "None"], ["100009", "None", "[2]", "INTAKE", "LEAKING", "None"], ["100010", "None", "[4]", "ROCKER COVER", "LEAKING", "None"], ["100021", "None", "[4]", "INTAKE", "LEAKING", "None"], ["100022", "None", "[2, 4]", "ROCKER COVER GASKETS", "LEAKING", "None"], ["100023", "None", "None", "ROCKER BOX COVER SCREWS", "LOOSE", "None"], ["100024", "None", "None", "INDUCTION TUBE HOSE CLAMPS", "LOOSE", "None"], ["100025", "None", "[1]", "INTAKE GASKET", "LEAKING", "None"], ["100026", "None", "None", "INDUCTION TUBE HOSE CLAMPS", "LOOSE", "None"], ["100027", "R", "None", "BLAST TUBE", "FELL_OFF", "None"], ["100028", "None", "None", "ENGINE", "ROUGH", "BEGAN TO RUN"], ["100029", "None", "None", "ENGINE", "ROUGH", "BEGAN TO RUN"], ["100030", "None", "None", "ENGINE", "ROUGH", "BEGAN TO RUN"], ["100041", "NaN", "[4]", "INTAKE", "LEAKING", "NaN"], ["100042", "NaN", "[3]", "ROCKER COVER GASKET", "LEAKING", "NaN"], ["100043", "L", "[1]", "BAFFLE", "CRACK", "HAS A"], ["100044", "NaN", "NaN", "OIL DIPSTICK", "LOOSE", "OIL STICK IS"], ["100045", "NaN", "[3]", "BRAKE", "MISSING", "SCREW"], ["100046", "R", "NaN", "BAFFLE SEALS", "TORN", "ON R/H SIDE ARE"], ["100047", "NaN", "[2, 4]", "ROCKER COVERS", "LEAKING", "NaN"], ["100048", "NaN", "[3]", "AFT BAFFLE BRACKET", "LOOSE", "NaN"], ["100049", "NaN", "[4]", "ROCKER COVER", "LEAKING", "NaN"], ["100050", "NaN", "[1, 2, 6]", "COWL MOUNTS", "TORN", "NaN"], ["100061", "NaN", "NaN", "ROCKER COVER GASKET", "LEAKING", "NaN"], ["100062", "ENGINE", "NaN", "NaN", "HIGH OIL PRESS", "NaN"], ["100063", "ENGINE", "NaN", "NaN", "HIGH OIL PRESS", "NaN"], ["100064", "NaN", "NaN", "NaN", "NaN", "COULDN'T START"], ["100065", "NaN", "NaN", "VACUUM TUBE & OIL COOLER LINE", "RUBBING", "NaN"], ["100066", "NaN", "NaN", "NaN", "NaN", "IDLE @ 970 RPM"], ["100067", "NaN", "NaN", "NaN", "FUEL PRESS", "NaN"], ["100068", "R", "[2]", "INTAKE", "LEAKS", "NaN"], ["100069", "L", "[4]", "BAFFLE", "CRACKED", "NaN"], ["100070", "R", "[4]", "BAFFLE", "CRACKED", "NaN"], ["100081", "None", "[2]", "INTAKE", "LEAKS", "None"], ["100082", "None", "[4]", "INTAKE", "LEAKS", "None"], ["100083", "None", "[3]", "INTAKE TUBE GASKET", "LEAKING", "None"], ["100084", "None", "[3, 4]", "ROCKER COVER GASKETS", "LEAKING", "None"], ["100085", "None", "None", "None", "START", "WOULD NOT"], ["100086", "None", "[2]", "INTAKE", "LEAKING", "None"], ["100087", "R", "None", "BAFFLE", "PULLED", "RIVET PULLED THROUGH"], ["100088", "None", "None", "ROCKER BOX COVER SCREWS", "LOOSE", "None"], ["100089", "None", "[2]", "INDUCTION TUBE GASKET", "LEAKING", "None"], ["100090", "None", "[2, 4]", "ROCKER COVERS", "LEAKING", "None"], ["100101", "R", "NaN", "FUSELAGE", "LEAK", "ENTIRE RIGHT SIDE"], ["100102", "R", "[4]", "ENGINE BAFFLE", "MISSING", "BOLT"], ["100103", "R", "[1, 4]", "ROCKER COVERS", "LEAKING", "NaN"], ["100104", "L", "[1, 3]", "ROCKER COVERS", "LEAKING", "NaN"], ["100105", "NaN", "NaN", "NaN", "DIED", "DURING MAG CK"], ["100106", "NaN", "[3]", "ROCKER COVER", "LEAKING", "GASKET"], ["100107", "NaN", "[2, 4]", "ROCKER COVER", "LEAKING", "GASKET"], ["100108", "NaN", "[2, 4]", "OIL RETURN LINE", "LOOSE", "CLAMPS"], ["100109", "R", "[2]", "INTAKE GASKET", "LEAKING", "NaN"], ["100110", "NaN", "NaN", "BAFFLE SEALS", "LOOSE", "UNDER BOTH PROP GOVERNORS"], ["100121", "NaN", "[4]", "INTAKE", "LEAKING", "NaN"], ["100122", "NaN", "[2]", "INTAKE", "LEAKING", "NaN"], ["100123", "NaN", "[4]" ...

# %%
p['engine'].value_counts()
# Out:
# R             561
# L             453
# F              11
# ENGINE          6
# R/H             5
# B               4
# LH              4
# LEFT            3
# AFT             2
# L/H             2
# ENG             2
# FWD ENGINE      1
# 1               1
# R/H ENGINE      1
# ALL ENG         1
# L/R             1
# A               1
# R, L            1
# null            1
# 3               1
# Name: engine, dtype: int64
